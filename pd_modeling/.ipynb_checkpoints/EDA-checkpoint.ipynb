# %% [markdown]
# ## EDA

# %%
# Importando las librerias 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn  as sns 
import warnings 
warnings.filterwarnings('ignore')
# Correccion
# Out:
# c:\Users\jpgz3\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# 1.- Importamos los datos.

# %%
DataCredit = pd.read_csv("credit_risk_data_v2.csv",low_memory=False)

# %%
DataCredit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           466285 non-null  int64
#  1   member_id                    466285 non-null  int64
#  2   loan_amnt                    466285 non-null  int64
#  3   funded_amnt                  466285 non-null  int64
#  4   funded_amnt_inv              466285 non-null  float64
#  5   term                         466285 non-null  object
#  6   int_rate                     466285 non-null  float64
#  7   installment                  466285 non-null  float64
#  8   grade                        466285 non-null  object
#  9   sub_grade                    466285 non-null  object
#  10  emp_title                    438697 non-null  object
#  11  emp_length                   445277 non-null  object
#  12  home_ownership               466285 non-null  object
#  13  annual_inc                   466281 non-null  float64
#  14  verification_status          466285 non-null  object
#  15  issue_d                      466285 non-null  object
#  16  pymnt_plan                   466285 non-null  object
#  17  url                          466285 non-null  object
#  18  desc                         125983 non-null  object
#  19  purpose                      466285 non-null  object
#  20  title                        466265 non-null  object
#  21  zip_code                     466285 non-null  object
#  22  addr_state                   466285 non-null  object
#  23  dti                          466285 non-null  float64
#  24  delinq_2yrs                  466256 non-null  float64
#  25  earliest_cr_line             466256 non-null  object
#  26  inq_last_6mths               466256 non-null  float64
#  27  mths_since_last_delinq       215934 non-null  float64
#  28  mths_since_last_record       62638 non-null   float64
#  29  open_acc                     466256 non-null  float64
#  30  pub_rec                      466256 non-null  float64
#  31  revol_bal                    466285 non-null  int64
#  32  revol_util                   465945 non-null  float64
#  33  total_acc                    466256 non-null  float64
#  34  initial_list_status          466285 non-null  object
#  35  out_prncp                    466285 non-null  float64
#  36  out_prncp_inv                466285 non-null  float64
#  37  total_pymnt                  466285 non-null  float64
#  38  total_pymnt_inv              466285 non-null  float64
#  39  total_rec_prncp              466285 non-null  float64
#  40  total_rec_int                466285 non-null  float64
#  41  total_rec_late_fee           466285 non-null  float64
#  42  recoveries                   466285 non-null  float64
#  43  collection_recovery_fee      466285 non-null  float64
#  44  last_pymnt_d                 465909 non-null  object
#  45  last_pymnt_amnt              466285 non-null  float64
#  46  next_pymnt_d                 239071 non-null  object
#  47  last_credit_pull_d           466243 non-null  object
#  48  collections_12_mths_ex_med   466140 non-null  float64
#  49  mths_since_last_major_derog  98974 non-null   float64
#  50  policy_code                  466285 non-null  int64
#  51  application_type             466285 non-null  object
#  52  annual_inc_joint             0 non-null       float64
#  53  dti_joint                    0 non-null       float64
#  54  verification_status_joint    0 non-null       float64
#  55  acc_now_delinq               466256 non-null  float64
#  56  tot_coll_amt                 396009 non-null  float64
#  57  tot_cur_bal                  396009 non-null  float64
#  58  open_acc_6m                  0 non-null       float64
#  59  open_il_6m                   0 non-null       float64
#  60  open_il_12m                  0 non-null       float64
#  61  open_il_24m                  0 non-null       float64
#  62  mths_since_rcnt_il           0 non-null       float64
#  63  total_bal_il                 0 non-null       float64
#  64  il_util                      0 non-null       float64
#  65  open_rv_12m                  0 non-null       float64
#  66  open_rv_24m                  0 non-null       float64
#  67  max_bal_bc                   0 non-null       float64
#  68  all_util                     0 non-null       float64
#  69  total_rev_hi_lim             396009 non-null  float64
#  70  inq_fi                       0 non-null       float64
#  71  total_cu_tl                  0 non-null       float64
#  72  inq_last_12m                 0 non-null       float64
#  73  status                       466285 non-null  int64
# dtypes: float64(46), int64(7), object(21)
# memory usage: 263.3+ MB

# %%
# Obtener una lista de las columnas que contienen solo valores en blanco
empty_columns = [col for col in DataCredit.columns if DataCredit[col].isnull().all()]
# Eliminar las columnas que contienen solo valores en blanco
DataCredit.drop(empty_columns, axis=1, inplace=True)
# Se borrran las columnas que son identificadores ya que no nos sirven para nuestros modelos 
DataCredit.drop(['id','member_id'],axis=1, inplace=True)
# btener una Serie con la cantidad de valores nulos en cada columna
null_counts = DataCredit.isnull().sum()
# Filtrar las columnas con valores nulos y ordenarlas de manera ascendente
null_cols = null_counts[null_counts > 0].sort_values()
# Imprimir las columnas con valores nulos
print(null_cols)
# Out:
# annual_inc                          4
# title                              20
# pub_rec                            29
# acc_now_delinq                     29
# delinq_2yrs                        29
# earliest_cr_line                   29
# inq_last_6mths                     29
# open_acc                           29
# total_acc                          29
# last_credit_pull_d                 42
# collections_12_mths_ex_med        145
# revol_util                        340
# last_pymnt_d                      376
# emp_length                      21008
# emp_title                       27588
# tot_coll_amt                    70276
# tot_cur_bal                     70276
# total_rev_hi_lim                70276
# next_pymnt_d                   227214
# mths_since_last_delinq         250351
# desc                           340302
# mths_since_last_major_derog    367311
# mths_since_last_record         403647
# dtype: int64

# %%
DataCredit.corr()
# Out:
#                              loan_amnt  funded_amnt  funded_amnt_inv  \
# loan_amnt                     1.000000     0.998548         0.994347
# funded_amnt                   0.998548     1.000000         0.996125
# funded_amnt_inv               0.994347     0.996125         1.000000
# int_rate                      0.167183     0.167921         0.169353
# installment                   0.949666     0.951787         0.947387
# annual_inc                    0.370893     0.370311         0.367806
# dti                           0.057319     0.058673         0.062606
# delinq_2yrs                   0.006841     0.007386         0.008143
# inq_last_6mths               -0.020328    -0.020970        -0.027580
# mths_since_last_delinq       -0.041361    -0.041443        -0.036670
# mths_since_last_record        0.011523     0.011622         0.056884
# open_acc                      0.204182     0.204983         0.205807
# pub_rec                      -0.081137    -0.080593        -0.078894
# revol_bal                     0.331423     0.331039         0.327436
# revol_util                    0.117756     0.118885         0.120774
# total_acc                     0.235262     0.235135         0.235456
# out_prncp                     0.518700     0.521451         0.525143
# out_prncp_inv                 0.518660     0.521412         0.525115
# total_pymnt                   0.743841     0.743363         0.738037
# total_pymnt_inv               0.743580     0.743441         0.745460
# total_rec_prncp               0.612777     0.612318         0.607027
# total_rec_int                 0.715876     0.715664         0.713460
# total_rec_late_fee            0.043650     0.043350         0.038985
# recoveries                    0.110691     0.110338         0.107944
# collection_recovery_fee       0.077336     0.077190         0.073781
# last_pymnt_amnt               0.304243     0.304178         0.303105
# collections_12_mths_ex_med   -0.008067    -0.007822        -0.007175
# mths_since_last_major_derog  -0.066374    -0.066359        -0.066301
# policy_code                        NaN          NaN              NaN
# acc_now_delinq                0.006283     0.006472         0.006801
# tot_coll_amt                 -0.002859    -0.002859        -0.002858
# tot_cur_bal                   0.332686     0.332683         0.332677
# total_rev_hi_lim              0.290208     0.290206         0.290185
# status                        0.011819     0.011003         0.007191
#
#                              int_rate  installment  annual_inc       dti  \
# loan_amnt                    0.167183     0.949666    0.370893  0.057319
# funded_amnt                  0.167921     0.951787    0.370311  0.058673
# funded_amnt_inv              0.169353     0.947387    0.367806  0.062606
# int_rate                     1.000000     0.148790   -0.046072  0.159657
# installment                  0.148790     1.000000    0.368145  0.049919
# annual_inc                  -0.046072     0.368145    1.000000 -0.188548
# dti                          0.159657     0.049919   -0.188548  1.000000
# delinq_2yrs                  0.079190     0.017001    0.058896 -0.003694
# inq_last_6mths               0.205641     0.002247    0.056675 -0.012541
# mths_since_last_delinq      -0.046605    -0.045757   -0.058960  0.007574
# mths_since_last_record      -0.008992    -0.002599   -0.097235  0.082449
# open_acc                     0.012307     0.196839    0.157784  0.303914
# pub_rec                      0.066695    -0.070093   -0.015439 -0.046192
# revol_bal                   -0.004589     0.320239    0.332316  0.143380
# revol_util                   0.323365     0.136852    0.037582  0.200412
# total_acc                   -0.033012     0.215906    0.224690  0.228221
# out_prncp                    0.137427     0.408838    0.168316  0.119984
# out_prncp_inv                0.137451     0.408811    0.168316  0.119972
# total_pymnt                  0.127035     0.764360    0.299784 -0.026007
# total_pymnt_inv              0.129166     0.763895    0.298728 -0.021788
# total_rec_prncp             -0.032130     0.663399    0.275823 -0.063895
# total_rec_int                0.485154     0.641948    0.212951  0.089582
# total_rec_late_fee           0.057875     0.052341    0.020273 -0.005747
# recoveries                   0.127893     0.105666    0.016954  0.021462
# collection_recovery_fee      0.082198     0.075344    0.013680  0.018084
# last_pymnt_amnt              0.075609     0.299867    0.142155 -0.043068
# collections_12_mths_ex_med   0.020306    -0.006055   -0.000445  0.000308
# mths_since_last_major_derog -0.006686    -0.066462   -0.068390  0.029121
# policy_code                       NaN          NaN         NaN       NaN
# acc_now_delinq               0.030338     0.008923    0.017133  0.009491
# tot_coll_amt                 0.000863    -0.002359    0.001895 -0.003560
# tot_cur_bal                 -0.097316     0.300639    0.486086 -0.018384
# total_rev_hi_lim            -0.146838     0.270074    0.291955  0.060972
# status                       0.172361     0.013936   -0.049864  0.048102
#
#                              delinq_2yrs  inq_last_6mths  \
# loan_amnt                       0.006841       -0.020328
# funded_amnt                     0.007386       -0.020970
# funded_amnt_inv                 0.008143       -0.027580
# int_rate                        0.079190        0.205641
# installment                     0.017001        0.002247
# annual_inc                      0.058896        0.056675
# dti                            -0.003694       -0.012541
# delinq_2yrs                     1.000000        0.017985
# inq_last_6mths                  0.017985        1.000000
# mths_since_last_delinq         -0.573957        0.005059
# mths_since_last_record         -0.074626       -0.118432
# open_acc                        0.059134        0.092788
# pub_rec                        -0.010810        0.038328
# revol_bal                      -0.031121       -0.015715
# revol_util                     -0.013183       -0.094701
# total_acc                       0.130793        0.124072
# out_prncp                       0.043857       -0.070402
# out_prncp_inv                   0.043852       -0.070392
# total_pymnt                    -0.019697        0.020644
# total_pymnt_inv                -0.018993        0.014769
# total_rec_prncp                -0.032098        0.005306
# total_rec_int                   0.024274        0.044068
# total_rec_late_fee              0.024428        0.029995
# recoveries                      0.004484        0.042945
# collection_recovery_fee         0.005382        0.032718
# last_pymnt_amnt                -0.013740        0.041229
# collections_12_mths_ex_med      0.039147       -0.001804
# mths_since_last_major_derog    -0.437091        0.017929
# policy_code                          NaN             NaN
# acc_now_delinq                  0.126532       -0.006918
# tot_coll_amt                    0.000072        0.001887
# tot_cur_bal                     0.072699        0.060198
# total_rev_hi_lim               -0.035028        0.008383
# status                          0.001227        0.073102
#
#                              mths_since_last_delinq  ...  \
# loan_amnt                                 -0.041361  ...
# funded_amnt                               -0.041443  ...
# funded_amnt_inv                           -0.036670  ...
# int_rate                                  -0.046605  ...
# installment                               -0.045757  ...
# annual_inc                                -0.058960  ...
# dti                                        0.007574  ...
# delinq_2yrs                               -0.573957  ...
# inq_last_6mths                             0.005059  ...
# mths_since_last_delinq                     1.000000  ...
# mths_since_last_record                     0.053133  ...
# open_acc                                  -0.047214  ...
# pub_rec                                    0.089453  ...
# revol_bal                                 -0.025841  ...
# revol_util                                 0.024544  ...
# total_acc                                 -0.057061  ...
# out_prncp                                 -0.049304  ...
# out_prncp_inv                             -0.049291  ...
# total_pymnt                               -0.011731  ...
# total_pymnt_inv                           -0.007179  ...
# total_rec_prncp                            0.000683  ...
# total_rec_int                             -0.038082  ...
# total_rec_late_fee                        -0.026263  ...
# recoveries                                -0.006545  ...
# collection_recovery_fee                   -0.007625  ...
# last_pymnt_amnt                            0.006630  ...
# collections_12_mths_ex_med                -0.032314  ...
# mths_since_last_major_derog                0.721514  ...
# policy_code                                     NaN  ...
# acc_now_delinq                            -0.130729  ...
# tot_coll_amt                               0.004010  ...
# tot_cur_bal                               -0.101063  ...
# total_rev_hi_lim                          -0.026288  ...
# status                                    -0.003338  ...
#
#                              collection_recovery_fee  last_pymnt_amnt  \
# loan_amnt                                   0.077336         0.304243
# funded_amnt                                 0.077190         0.304178
# funded_amnt_inv                             0.073781         0.303105
# int_rate                                    0.082198         0.075609
# installment                                 0.075344         0.299867
# annual_inc                                  0.013680         0.142155
# dti                                         0.018084        -0.043068
# delinq_2yrs                                 0.005382        -0.013740
# inq_last_6mths                              0.032718         0.041229
# mths_since_last_delinq                     -0.007625         0.006630
# mths_since_last_record                     -0.010755         0.039021
# open_acc                                    0.012086         0.054893
# pub_rec                                    -0.007006        -0.027236
# revol_bal                                   0.015156         0.087132
# revol_util                                  0.021157        -0.010453
# total_acc                                   0.016155         0.113011
# out_prncp                                  -0.072742        -0.317381
# out_prncp_inv                              -0.072737        -0.317359
# total_pymnt                                -0.000890         0.614276
# total_pymnt_inv                            -0.003728         0.614216
# total_rec_prncp                            -0.073920         0.709676
# total_rec_int                               0.028152         0.050888
# total_rec_late_fee                          0.069015        -0.034820
# recoveries                                  0.800666        -0.070722
# collection_recovery_fee                     1.000000        -0.047792
# last_pymnt_amnt                            -0.047792         1.000000
# collections_12_mths_ex_med                 -0.000369        -0.009801
# mths_since_last_major_derog                -0.008082        -0.016756
# policy_code                                      NaN              NaN
# acc_now_delinq                              0.001381        -0.000998
# tot_coll_amt                               -0.000309        -0.001591
# tot_cur_bal                                 0.009096         0.132397
# total_rev_hi_lim                            0.007079         0.087543
# status                                      0.299227        -0.168030
#
#                              collections_12_mths_ex_med  \
# loan_amnt                                     -0.008067
# funded_amnt                                   -0.007822
# funded_amnt_inv                               -0.007175
# int_rate                                       0.020306
# installment                                   -0.006055
# annual_inc                                    -0.000445
# dti                                            0.000308
# delinq_2yrs                                    0.039147
# inq_last_6mths                                -0.001804
# mths_since_last_delinq                        -0.032314
# mths_since_last_record                        -0.017268
# open_acc                                       0.011852
# pub_rec                                        0.021524
# revol_bal                                     -0.016156
# revol_util                                    -0.027682
# total_acc                                      0.013263
# out_prncp                                      0.020330
# out_prncp_inv                                  0.020323
# total_pymnt                                   -0.024750
# total_pymnt_inv                               -0.024126
# total_rec_prncp                               -0.026177
# total_rec_int                                 -0.008024
# total_rec_late_fee                            -0.000537
# recoveries                                    -0.001023
# collection_recovery_fee                       -0.000369
# last_pymnt_amnt                               -0.009801
# collections_12_mths_ex_med                     1.000000
# mths_since_last_major_derog                   -0.074566
# policy_code                                         NaN
# acc_now_delinq                                 0.019299
# tot_coll_amt                                   0.006721
# tot_cur_bal                                   -0.004456
# total_rev_hi_lim                              -0.011618
# status                                        -0.005114
#
#                              mths_since_last_major_derog  policy_code  \
# loan_amnt                                      -0.066374          NaN
# funded_amnt                                    -0.066359          NaN
# funded_amnt_inv                                -0.066301          NaN
# int_rate                                       -0.006686          NaN
# installment                                    -0.066462          NaN
# annual_inc                                     -0.068390          NaN
# dti                                             0.029121          NaN
# delinq_2yrs                                    -0.437091          NaN
# inq_last_6mths                                  0.017929          NaN
# mths_since_last_delinq                          0.721514          NaN
# mths_since_last_record                          0.002451          NaN
# open_acc                                       -0.002778          NaN
# pub_rec                                         0.116682          NaN
# revol_bal                                      -0.046006          NaN
# revol_util                                     -0.013619          NaN
# total_acc                                      -0.069413          NaN
# out_prncp                                      -0.026168          NaN
# out_prncp_inv                                  -0.026148          NaN
# total_pymnt                                    -0.059333          NaN
# total_pymnt_inv                                -0.059284          NaN
# total_rec_prncp                                -0.049380          NaN
# total_rec_int                                  -0.053026          NaN
# total_rec_late_fee                             -0.010640          NaN
# recoveries                                     -0.011080          NaN
# collection_recovery_fee                        -0.008082          NaN
# last_pymnt_amnt                                -0.016756          NaN
# collections_12_mths_ex_med                     -0.074566          NaN
# mths_since_last_major_derog                     1.000000          NaN
# policy_code                                          NaN          NaN
# acc_now_delinq                                 -0.114796          NaN
# tot_coll_amt                                    0.003008          NaN
# tot_cur_bal                                    -0.100544          NaN
# total_rev_hi_lim                               -0.050463          NaN
# status                                         -0.003873          NaN
#
#                              acc_now_delinq  tot_coll_amt  tot_cur_bal  \
# loan_amnt                          0.006283     -0.002859     0.332686
# funded_amnt                        0.006472     -0.002859     0.332683
# funded_amnt_inv                    0.006801     -0.002858     0.332677
# int_rate                           0.030338      0.000863    -0.097316
# installment                        0.008923     -0.002359     0.300639
# annual_inc                         0.017133      0.001895     0.486086
# dti                                0.009491     -0.003560    -0.018384
# delinq_2yrs                        0.126532      0.000072     0.072699
# inq_last_6mths                    -0.006918      0.001887     0.060198
# mths_since_last_delinq            -0.130729      0.004010    -0.101063
# mths_since_last_record            -0.018672     -0.075909    -0.026245
# open_acc                           0.018194     -0.000467     0.243536
# pub_rec                            0.002348      0.003973    -0.075161
# revol_bal                          0.001000     -0.004106     0.426826
# revol_util                        -0.022752     -0.006167     0.069305
# total_acc                          0.027718      0.005045     0.317500
# out_prncp                          0.016475     -0.000802     0.169798
# out_prncp_inv                      0.016471     -0.000803     0.169800
# total_pymnt                       -0.004292     -0.002524     0.257000
# total_pymnt_inv                   -0.003955     -0.002522     0.257010
# total_rec_prncp                   -0.008617     -0.002110     0.234614
# total_rec_int                      0.009491     -0.002196     0.179018
# total_rec_late_fee                 0.003456     -0.000422     0.012138
# recoveries                         0.002763     -0.000625     0.007003
# collection_recovery_fee            0.001381     -0.000309     0.009096
# last_pymnt_amnt                   -0.000998     -0.001591     0.132397
# collections_12_mths_ex_med         0.019299      0.006721    -0.004456
# mths_since_last_major_derog       -0.114796      0.003008    -0.100544
# policy_code                             NaN           NaN          NaN
# acc_now_delinq                     1.000000     -0.000017     0.023723
# tot_coll_amt                      -0.000017      1.000000     0.000740
# tot_cur_bal                        0.023723      0.000740     1.000000
# total_rev_hi_lim                   0.009244     -0.003224     0.356388
# status                            -0.000197     -0.001209    -0.051197
#
#                              total_rev_hi_lim    status
# loan_amnt                            0.290208  0.011819
# funded_amnt                          0.290206  0.011003
# funded_amnt_inv                      0.290185  0.007191
# int_rate                            -0.146838  0.172361
# installment                          0.270074  0.013936
# annual_inc                           0.291955 -0.049864
# dti                                  0.060972  0.048102
# delinq_2yrs                         -0.035028  0.001227
# inq_last_6mths                       0.008383  0.073102
# mths_since_last_delinq              -0.026288 -0.003338
# mths_since_last_record              -0.021948  0.022837
# open_acc                             0.290747 -0.006174
# pub_rec                             -0.095906 -0.009111
# revol_bal                            0.809930 -0.018348
# revol_util                          -0.125469  0.050207
# total_acc                            0.232194 -0.023069
# out_prncp                            0.149447 -0.158676
# out_prncp_inv                        0.149438 -0.158662
# total_pymnt                          0.211101 -0.194438
# total_pymnt_inv                      0.211101 -0.195169
# total_rec_prncp                      0.201842 -0.253875
# total_rec_int                        0.120626 -0.026726
# total_rec_late_fee                  -0.003501  0.147750
# recoveries                           0.006407  0.441171
# collection_recovery_fee              0.007079  0.299227
# last_pymnt_amnt                      0.087543 -0.168030
# collections_12_mths_ex_med          -0.011618 -0.005114
# mths_since_last_major_derog         -0.050463 -0.003873
# policy_code                               NaN       NaN
# acc_now_delinq                       0.009244 -0.000197
# tot_coll_amt                        -0.003224 -0.001209
# tot_cur_bal                          0.356388 -0.051197
# total_rev_hi_lim                     1.000000 -0.037165
# status                              -0.037165  1.000000
#
# [34 rows x 34 columns]

# %% [markdown]
# Despues de hacer el analisis de las variables o columnas que vamos a utilizar decidimos utilzar estas.

# %% [markdown]
# Variables bins
# 1. loan_amnt
# 2. int_rate
# 3. installment
# 4. emp_length
# 5. annual_incc
# 6.  dti
# 7. revol_bal
# 8. revol_util
# 9.  total_acc
# 10. total_pymnt
# 11. total_rec_prncp
# 12. total_rec_int
# 13. recoveris
# 14. last_pymnt_amnt
#
# no bins
# 1. grade
# 2. term
# 3. home_ownership
# 4. purpose
# 5. pymnt_plan
# 6. addr_state
# 7. initial_list_status
# 8. status

# %%
ListColumns = ['loan_amnt','int_rate','installment','emp_length',
               'annual_inc','dti','revol_bal','revol_util','total_acc',
               'total_pymnt','total_rec_prncp','total_rec_int','recoveries',
               'last_pymnt_amnt','grade','term','home_ownership','purpose',
               'pymnt_plan','addr_state','initial_list_status','status']
DataCredit_clean = DataCredit[ListColumns]

# %%
DataCredit_clean.describe()
# Out:
#            loan_amnt       int_rate    installment    annual_inc  \
# count  466285.000000  466285.000000  466285.000000  4.662810e+05
# mean    14317.277577      13.829236     432.061201  7.327738e+04
# std      8286.509164       4.357587     243.485550  5.496357e+04
# min       500.000000       5.420000      15.670000  1.896000e+03
# 25%      8000.000000      10.990000     256.690000  4.500000e+04
# 50%     12000.000000      13.660000     379.890000  6.300000e+04
# 75%     20000.000000      16.490000     566.580000  8.896000e+04
# max     35000.000000      26.060000    1409.990000  7.500000e+06
#
#                  dti     revol_bal     revol_util      total_acc  \
# count  466285.000000  4.662850e+05  465945.000000  466256.000000
# mean       17.218758  1.623020e+04      56.176947      25.064430
# std         7.851121  2.067625e+04      23.732628      11.600141
# min         0.000000  0.000000e+00       0.000000       1.000000
# 25%        11.360000  6.413000e+03      39.200000      17.000000
# 50%        16.870000  1.176400e+04      57.600000      23.000000
# 75%        22.780000  2.033300e+04      74.700000      32.000000
# max        39.990000  2.568995e+06     892.300000     156.000000
#
#          total_pymnt  total_rec_prncp  total_rec_int     recoveries  \
# count  466285.000000    466285.000000  466285.000000  466285.000000
# mean    11540.686220      8866.014657    2588.677225      85.344211
# std      8265.627112      7031.687997    2483.809661     552.216084
# min         0.000000         0.000000       0.000000       0.000000
# 25%      5552.125349      3708.560000     957.280000       0.000000
# 50%      9419.250943      6817.760000    1818.880000       0.000000
# 75%     15308.158460     12000.000000    3304.530000       0.000000
# max     57777.579870     35000.030000   24205.620000   33520.270000
#
#        last_pymnt_amnt         status
# count    466285.000000  466285.000000
# mean       3123.913796       0.109307
# std        5554.737393       0.312024
# min           0.000000       0.000000
# 25%         312.620000       0.000000
# 50%         545.960000       0.000000
# 75%        3187.510000       0.000000
# max       36234.440000       1.000000

# %% [markdown]
# # Visualizaciones
